# %%
import numpy as np
X_test = np.load('/kaggle/input/datasets/minhquang2611/eeg-data/X_test_final.npy')
X_train = np.load('/kaggle/input/datasets/minhquang2611/eeg-data/X_train_final.npy')
y_test = np.load('/kaggle/input/datasets/minhquang2611/eeg-data/y_test_final.npy')
y_train = np.load('/kaggle/input/datasets/minhquang2611/eeg-data/y_train_final.npy')

# %%
print(X_test.shape)
print(X_train.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (14694, 64, 129)
# (58671, 64, 129)
# (58671,)
# (14694,)

# %%
import torch
import torch.nn as nn

# %%
# Assuming your scaled data is 'X_train_scaled' with shape (36765, 64, 97)
# Use .unsqueeze(1) to add that "1" in the second position
X_train_dl = torch.from_numpy(X_train).float().unsqueeze(1)
X_test_dl = torch.from_numpy(X_test).float().unsqueeze(1)
# Convert your labels to a 1D LongTensor
y_train_tensor = torch.from_numpy(y_train).long()
y_test_tensor = torch.from_numpy(y_test).long()

print(y_train_tensor.shape)  # Should show torch.Size([36765])
print(y_train_tensor.dtype)  # Should show torch.int64 (which is Long)
print(X_train_dl.shape)
print(X_test_dl.shape)
# Out:
# torch.Size([58671])
# torch.int64
# torch.Size([58671, 1, 64, 129])
# torch.Size([14694, 1, 64, 129])

# %%
import torch
import torch.nn as nn

class EEGNet(nn.Module):
    def __init__(self, num_classes, Chans=64, Samples=129):
        super(EEGNet, self).__init__()

        # F1: Number of temporal filters
        # D: Depth multiplier (spatial filters per temporal filter)
        F1 = 16
        D = 2
        F2 = F1 * D  # 32

        # 1. Temporal Convolution (Frequency Filter)
        # Using kernel 32 (0.2s at 160Hz) provides better "sliding" room for a 0.8s window
        self.conv1 = nn.Conv2d(1, F1, kernel_size=(1, 64), padding=(0, 32), bias=False)
        self.bn1 = nn.BatchNorm2d(F1, momentum=0.01, eps=0.001)

        # 2. Depthwise Convolution (Spatial Filter / "AI CSP")
        # groups=F1 ensures each temporal filter gets its own spatial filter
        self.depthwise_conv = nn.Conv2d(F1, F2, kernel_size=(Chans, 1), groups=F1, bias=False)
        self.bn2 = nn.BatchNorm2d(F2, momentum=0.01, eps=0.001)
        self.elu = nn.ELU() # ELU is preferred over ReLU for EEG
        self.pool2 = nn.AvgPool2d(kernel_size=(1, 4), stride=(1, 4))
        self.dropout2 = nn.Dropout(p=0.4)

        # 3. Separable Convolution (Temporal refinement)
        self.separable_conv = nn.Conv2d(F2, F2, kernel_size=(1, 15), padding=(0, 7), groups=F2, bias=False)
        self.bn3 = nn.BatchNorm2d(F2, momentum=0.01, eps=0.001)
        self.pool3 = nn.AvgPool2d(kernel_size=(1, 8), stride=(1, 8))
        self.dropout3 = nn.Dropout(p=0.4)

        # 4. Fully Connected Layer
        # Math: 32 filters * 4 remaining timepoints = 128
        self.fc1 = nn.Linear(128, num_classes)

    def forward(self, x):
        # Layer 1: Temporal
        x = self.bn1(self.conv1(x))

        # Layer 2: Spatial
        x = self.elu(self.bn2(self.depthwise_conv(x)))
        x = self.pool2(x)
        x = self.dropout2(x)

        # Layer 3: Separable
        x = self.elu(self.bn3(self.separable_conv(x)))
        x = self.pool3(x)
        x = self.dropout3(x)

        # Flatten and Classify
        x = x.view(x.size(0), -1) # Flattening to (Batch, 128)
        return self.fc1(x)

# %%
# Set your batch size (64 is a good balance for Colab's T4 GPU)
batch_size = 128

# %%
# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Initialize and move the model
num_classes = 3
model = EEGNet(num_classes=num_classes).to(device)
# Out:
# Using device: cuda

# %%
from torch.utils.data import random_split, DataLoader, TensorDataset

# 1. Create the full dataset
full_dataset = TensorDataset(X_train_dl, y_train_tensor)

# 2. Split into Train (90%) and Validation (10%)
train_size = int(0.9 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_subset, val_subset = random_split(full_dataset, [train_size, val_size])

# 3. Create Loaders
train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

# 4. Define Weighted Loss to fix "Rest" bias
#class_weights = torch.tensor([1.0, 2.0, 2.2]).to(device)
class_weights = torch.tensor([0.66, 1.30, 1.38]).to(device)

# %%
# Replace your old criterion with this:
criterion = torch.nn.CrossEntropyLoss(weight=class_weights)
# criterion = FocalLoss(weight=class_weights, gamma=2.0)

# Create the optimizer as before
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Add the scheduler
# 'min' mode means it waits for the loss to stop decreasing
# 'patience' is how many epochs to wait before cutting the LR
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=15)

# %%
epochs = 150 # Increased epochs because the scheduler will keep training productive for longer
best_val_acc = 0.0
for epoch in range(epochs):
    # --- TRAINING PHASE ---
    model.train()
    train_loss = 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        # Add noise
        noise = torch.randn_like(inputs) * 0.01 
        inputs = inputs + noise
        # Randomly zero out 2 channels out of 64
        if model.training:
          mask = torch.ones(64).to(device)
          mask[torch.randint(0, 64, (2,))] = 0
          inputs = inputs * mask.view(1, 1, 64, 1)

        optimizer.zero_grad()
        outputs = model(inputs) # Math: 128 inputs to the FC layer
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    # --- VALIDATION PHASE ---
    model.eval()
    val_loss = 0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels) # Still using the weighted loss
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    avg_train_loss = train_loss / len(train_loader)
    avg_val_loss = val_loss / len(val_loader)
    val_acc = 100 * val_correct /  val_total

    # IMPORTANT: The scheduler looks at the validation loss to decide when to drop the LR
    scheduler.step(avg_val_loss)
    # MANUALLY GET THE CURRENT LEARNING RATE
    current_lr = optimizer.param_groups[0]['lr']

    print(f"Epoch {epoch+1:02d} | LR: {current_lr:.10f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f} | Val Acc: {val_acc:.2f}%")
    # --- ADD THIS AT THE BOTTOM OF YOUR EPOCH LOOP ---
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        # This saves the 'brain' (weights) to a file named best_model.pth
        torch.save(model.state_dict(), 'best_eegnet_model.pth')
        print(f"✨ New Best Model Saved! Accuracy: {best_val_acc:.2f}%")
    # Save every 10 epochs as a recovery point
    if (epoch + 1) % 10 == 0:
      torch.save({
          'epoch': epoch,
          'model_state_dict': model.state_dict(),
          'optimizer_state_dict': optimizer.state_dict(),
          'val_acc': val_acc,
      }, f'checkpoint_epoch_{epoch+1}.pth')
# Out:
# Epoch 01 | LR: 0.0010000000 | Train Loss: 1.0809 | Val Loss: 1.0444 | Val Acc: 37.93%
# ✨ New Best Model Saved! Accuracy: 37.93%
# Epoch 02 | LR: 0.0010000000 | Train Loss: 1.0318 | Val Loss: 0.9830 | Val Acc: 48.45%
# ✨ New Best Model Saved! Accuracy: 48.45%
# Epoch 03 | LR: 0.0010000000 | Train Loss: 1.0087 | Val Loss: 0.9633 | Val Acc: 50.68%
# ✨ New Best Model Saved! Accuracy: 50.68%
# Epoch 04 | LR: 0.0010000000 | Train Loss: 0.9931 | Val Loss: 0.9448 | Val Acc: 52.25%
# ✨ New Best Model Saved! Accuracy: 52.25%
# Epoch 05 | LR: 0.0010000000 | Train Loss: 0.9813 | Val Loss: 0.9315 | Val Acc: 54.11%
# ✨ New Best Model Saved! Accuracy: 54.11%
# Epoch 06 | LR: 0.0010000000 | Train Loss: 0.9691 | Val Loss: 0.9133 | Val Acc: 54.91%
# ✨ New Best Model Saved! Accuracy: 54.91%
# Epoch 07 | LR: 0.0010000000 | Train Loss: 0.9637 | Val Loss: 0.9092 | Val Acc: 56.05%
# ✨ New Best Model Saved! Accuracy: 56.05%
# Epoch 08 | LR: 0.0010000000 | Train Loss: 0.9576 | Val Loss: 0.9025 | Val Acc: 56.53%
# ✨ New Best Model Saved! Accuracy: 56.53%
# Epoch 09 | LR: 0.0010000000 | Train Loss: 0.9554 | Val Loss: 0.8984 | Val Acc: 55.90%
# Epoch 10 | LR: 0.0010000000 | Train Loss: 0.9509 | Val Loss: 0.8935 | Val Acc: 55.21%
# Epoch 11 | LR: 0.0010000000 | Train Loss: 0.9479 | Val Loss: 0.8951 | Val Acc: 56.60%
# ✨ New Best Model Saved! Accuracy: 56.60%
# Epoch 12 | LR: 0.0010000000 | Train Loss: 0.9444 | Val Loss: 0.8882 | Val Acc: 58.98%
# ✨ New Best Model Saved! Accuracy: 58.98%
# Epoch 13 | LR: 0.0010000000 | Train Loss: 0.9396 | Val Loss: 0.8801 | Val Acc: 57.99%
# Epoch 14 | LR: 0.0010000000 | Train Loss: 0.9390 | Val Loss: 0.8799 | Val Acc: 60.48%
# ✨ New Best Model Saved! Accuracy: 60.48%
# Epoch 15 | LR: 0.0010000000 | Train Loss: 0.9373 | Val Loss: 0.8784 | Val Acc: 57.29%
# Epoch 16 | LR: 0.0010000000 | Train Loss: 0.9351 | Val Loss: 0.8834 | Val Acc: 55.40%
# Epoch 17 | LR: 0.0010000000 | Train Loss: 0.9333 | Val Loss: 0.8728 | Val Acc: 57.40%
# Epoch 18 | LR: 0.0010000000 | Train Loss: 0.9339 | Val Loss: 0.8786 | Val Acc: 57.94%
# Epoch 19 | LR: 0.0010000000 | Train Loss: 0.9343 | Val Loss: 0.8709 | Val Acc: 58.95%
# Epoch 20 | LR: 0.0010000000 | Train Loss: 0.9314 | Val Loss: 0.8703 | Val Acc: 60.94%
# ✨ New Best Model Saved! Accuracy: 60.94%
# Epoch 21 | LR: 0.0010000000 | Train Loss: 0.9248 | Val Loss: 0.8610 | Val Acc: 59.39%
# Epoch 22 | LR: 0.0010000000 | Train Loss: 0.9240 | Val Loss: 0.8744 | Val Acc: 56.51%
# Epoch 23 | LR: 0.0010000000 | Train Loss: 0.9263 | Val Loss: 0.8619 | Val Acc: 60.28%
# Epoch 24 | LR: 0.0010000000 | Train Loss: 0.9235 | Val Loss: 0.8714 | Val Acc: 58.16%
# Epoch 25 | LR: 0.0010000000 | Train Loss: 0.9226 | Val Loss: 0.8618 | Val Acc: 61.62%
# ✨ New Best Model Saved! Accuracy: 61.62%
# Epoch 26 | LR: 0.0010000000 | Train Loss: 0.9212 | Val Loss: 0.8674 | Val Acc: 57.62%
# Epoch 27 | LR: 0.0010000000 | Train Loss: 0.9208 | Val Loss: 0.8647 | Val Acc: 60.07%
# Epoch 28 | LR: 0.0010000000 | Train Loss: 0.9203 | Val Loss: 0.8578 | Val Acc: 61.69%
# ✨ New Best Model Saved! Accuracy: 61.69%
# Epoch 29 | LR: 0.0010000000 | Train Loss: 0.9185 | Val Loss: 0.8606 | Val Acc: 58.86%
# Epoch 30 | LR: 0.0010000000 | Train Loss: 0.9207 | Val Loss: 0.8608 | Val Acc: 61.57%
# Epoch 31 | LR: 0.0010000000 | Train Loss: 0.9139 | Val Loss: 0.8626 | Val Acc: 58.81%
# Epoch 32 | LR: 0.0010000000 | Train Loss: 0.9183 | Val Loss: 0.8578 | Val Acc: 59.46%
# Epoch 33 | LR: 0.0010000000 | Train Loss: 0.9205 | Val Loss: 0.8581 | Val Acc: 59.41%
# Epoch 34 | LR: 0.0010000000 | Train Loss: 0.9145 | Val Loss: 0.8555 | Val Acc: 61.98%
# ✨ New Best Model Saved! Accuracy: 61.98%
# Epoch 35 | LR: 0.0010000000 | Train Loss: 0.9173 | Val Loss: 0.8539 | Val Acc: 60.22%
# Epoch 36 | LR: 0.0010000000 | Train Loss: 0.9126 | Val Loss: 0.8540 | Val Acc: 59.68%
# Epoch 37 | LR: 0.0010000000 | Train Loss: 0.9130 | Val Loss: 0.8561 | Val Acc: 62.58%
# ✨ New Best Model Saved! Accuracy: 62.58%
# Epoch 38 | LR: 0.0010000000 | Train Loss: 0.9145 | Val Loss: 0.8578 | Val Acc: 60.33%
# Epoch 39 | LR: 0.0010000000 | Train Loss: 0.9105 | Val Loss: 0.8516 | Val Acc: 61.40%
# Epoch 40 | LR: 0.0010000000 | Train Loss: 0.9112 | Val Loss: 0.8482 | Val Acc: 61.86%
# Epoch 41 | LR: 0.0010000000 | Train Loss: 0.9103 | Val Loss: 0.8510 | Val Acc: 62.63%
# ✨ New Best Model Saved! Accuracy: 62.63%
# Epoch 42 | LR: 0.0010000000 | Train Loss: 0.9108 | Val Loss: 0.8496 | Val Acc: 62.80%
# ✨ New Best Model Saved! Accuracy: 62.80%
# Epoch 43 | LR: 0.0010000000 | Train Loss: 0.9108 | Val Loss: 0.8581 | Val Acc: 63.50%
# ✨ New Best Model Saved! Accuracy: 63.50%
# Epoch 44 | LR: 0.0010000000 | Train Loss: 0.9072 | Val Loss: 0.8449 | Val Acc: 63.10%
# Epoch 45 | LR: 0.0010000000 | Train Loss: 0.9095 | Val Loss: 0.8460 | Val Acc: 62.68%
# Epoch 46 | LR: 0.0010000000 | Train Loss: 0.9100 | Val Loss: 0.8556 | Val Acc: 61.59%
# Epoch 47 | LR: 0.0010000000 | Train Loss: 0.9083 | Val Loss: 0.8447 | Val Acc: 62.97%
# Epoch 48 | LR: 0.0010000000 | Train Loss: 0.9072 | Val Loss: 0.8512 | Val Acc: 61.74%
# Epoch 49 | LR: 0.0010000000 | Train Loss: 0.9105 | Val Loss: 0.8450 | Val Acc: 60.63%
# Epoch 50 | LR: 0.0010000000 | Train Loss: 0.9084 | Val Loss: 0.8414 | Val Acc: 63.45%
# Epoch 51 | LR: 0.0010000000 | Train Loss: 0.9066 | Val Loss: 0.8473 | Val Acc: 61.66%
# Epoch 52 | LR: 0.0010000000 | Train Loss: 0.9058 | Val Loss: 0.8447 | Val Acc: 60.97%
# Epoch 53 | LR: 0.0010000000 | Train Loss: 0.9082 | Val Loss: 0.8414 | Val Acc: 64.16%
# ✨ New Best Model Saved! Accuracy: 64.16%
# Epoch 54 | LR: 0.0010000000 | Train Loss: 0.9055 | Val Loss: 0.8493 | Val Acc: 58.74%
# Epoch 55 | LR: 0.0010000000 | Train Loss: 0.9078 | Val Loss: 0.8422 | Val Acc: 60.65%
# Epoch 137 | LR: 0.0000100000 | Train Loss: 0.8818 | Val Loss: 0.8318 | Val Acc: 63.41%
# Epoch 138 | LR: 0.0000100000 | Train Loss: 0.8808 | Val Loss: 0.8309 | Val Acc: 63.26%
# Epoch 139 | LR: 0.0000100000 | Train Loss: 0.8872 | Val Loss: 0.8293 | Val Acc: 63.60%
# Epoch 140 | LR: 0.0000100000 | Train Loss: 0.8851 | Val Loss: 0.8293 | Val Acc: 64.01%
# Epoch 141 | LR: 0.0000010000 | Train Loss: 0.8840 | Val Loss: 0.8296 | Val Acc: 63.65%
# Epoch 142 | LR: 0.0000010000 | Train Loss: 0.8827 | Val Loss: 0.8306 | Val Acc: 63.48%
# Epoch 143 | LR: 0.0000010000 | Train Loss: 0.8845 | Val Loss: 0.8296 | Val Acc: 63.60%
# Epoch 144 | LR: 0.0000010000 | Train Loss: 0.8870 | Val Loss: 0.8310 | Val Acc: 63.50%
# Epoch 145 | LR: 0.0000010000 | Train Loss: 0.8836 | Val Loss: 0.8295 | Val Acc: 63.87%
# Epoch 146 | LR: 0.0000010000 | Train Loss: 0.8838 | Val Loss: 0.8282 | Val Acc: 63.84%
# Epoch 147 | LR: 0.0000010000 | Train Loss: 0.8853 | Val Loss: 0.8303 | Val Acc: 63.58%
# Epoch 148 | LR: 0.0000010000 | Train Loss: 0.8865 | Val Loss: 0.8298 | Val Acc: 63.58%
# Epoch 149 | LR: 0.0000010000 | Train Loss: 0.8839 | Val Loss: 0.8274 | Val Acc: 63.97%
# Epoch 150 | LR: 0.0000010000 | Train Loss: 0.8838 | Val Loss: 0.8300 | Val Acc: 63.48%

# %%
# Wrap your test data
test_dataset = TensorDataset(X_test_dl, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# --- RUN THIS AFTER TRAINING IS TOTALLY FINISHED ---
model.load_state_dict(torch.load('best_eegnet_model.pth'))
model.to(device)
print("✅ Best weights reloaded. Ready for testing!")
# Out:
# ✅ Best weights reloaded. Ready for testing!

# %%
model.eval()  # Set model to evaluation mode
correct = 0
total = 0

# No gradients needed for testing
with torch.no_grad():
    for inputs, labels in test_loader:
        # Move to GPU
        inputs, labels = inputs.to(device), labels.to(device)

        # Get predictions
        outputs = model(inputs)

        # The class with the highest energy is our prediction
        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Final Accuracy on the {total} test samples: {accuracy:.2f}%')
# Out:
# Final Accuracy on the 14694 test samples: 53.05%

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 1. Gather all predictions from the test set
all_preds = []
all_labels = []

model.eval() # Important: turn off dropout
with torch.no_grad(): # Important: save memory
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1) # Get the index of the highest score

        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# 2. Generate the Matrix
# Assuming 0: Rest, 1: Left, 2: Right (check your label encoding!)
class_names = ['Rest', 'Left', 'Right']
cm = confusion_matrix(all_labels, all_preds)

# 3. Visualize
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel('AI Predicted')
plt.ylabel('Actual Truth')
plt.title('EEGNet Confusion Matrix')
plt.show()

# 4. Print detailed stats
print(classification_report(all_labels, all_preds, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#         Rest       0.62      0.72      0.66      7380
#         Left       0.44      0.38      0.41      3761
#        Right       0.37      0.30      0.33      3553
#
#     accuracy                           0.53     14694
#    macro avg       0.48      0.47      0.47     14694
# weighted avg       0.51      0.53      0.52     14694

# %%
# !pip install onnx
# !pip install onnxscript
# Out:
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (1.20.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.4)
# Collecting onnxscript
#   Downloading onnxscript-0.6.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (from onnxscript) (0.5.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from onnxscript) (2.0.2)
# Collecting onnx_ir<2,>=0.1.15 (from onnxscript)
#   Downloading onnx_ir-0.2.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: onnx>=1.17 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (1.20.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxscript) (25.0)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (4.15.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.17->onnxscript) (5.29.5)
# Requirement already satisfied: sympy>=1.13 in /usr/local/lib/python3.12/dist-packages (from onnx_ir<2,>=0.1.15->onnxscript) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13->onnx_ir<2,>=0.1.15->onnxscript) (1.3.0)
# Downloading onnxscript-0.6.2-py3-none-any.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.1/689.1 kB 19.3 MB/s eta 0:00:0000:01
# Downloading onnx_ir-0.2.0-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 13.6 MB/s eta 0:00:00
# Installing collected packages: onnx_ir, onnxscript
# Successfully installed onnx_ir-0.2.0 onnxscript-0.6.2

# %%
model.eval()
model.cpu()

example_inputs = (torch.randn(1, 1, 64, 129),)

torch.onnx.export(
    model,
    example_inputs,
    "eegnet_model.onnx",
    export_params=True,
    opset_version=14,
    input_names=['input'],
    output_names=['output'],
    dynamic_axes={
        'input': {0: 'batch_size'},   # make batch dimension dynamic
        'output': {0: 'batch_size'}   # same for output
    }
)

print("Export successful!")

# Verify
import onnx
onnx_model = onnx.load("eegnet_model.onnx")
onnx.checker.check_model(onnx_model)
print("Model is valid!")
# Out:
# /tmp/ipykernel_55/3469294764.py:6: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# W0301 19:40:22.681000 55 torch/onnx/_internal/exporter/_compat.py:114] Setting ONNX exporter to use operator set version 18 because the requested opset_version 14 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# [torch.onnx] Obtain model graph for `EEGNet([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `EEGNet([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 14).
# Failed to convert the model to the target version 14 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/__init__.py", line 120, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/__init__.py", line 115, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnx/version_converter.py", line 39, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: /github/workspace/onnx/version_converter/BaseConverter.h:68: adapter_lookup: Assertion `false` failed: No Adapter From Version $16 for Identity
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# Applied 11 of general pattern rewrite rules.
# Export successful!
# Model is valid!

# %%
model.to(device)  # move back after export
# Out:
# EEGNet(
#   (conv1): Conv2d(1, 16, kernel_size=(1, 64), stride=(1, 1), padding=(0, 32), bias=False)
#   (bn1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#   (depthwise_conv): Conv2d(16, 32, kernel_size=(64, 1), stride=(1, 1), groups=16, bias=False)
#   (bn2): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#   (elu): ELU(alpha=1.0)
#   (pool2): AvgPool2d(kernel_size=(1, 4), stride=(1, 4), padding=0)
#   (dropout2): Dropout(p=0.4, inplace=False)
#   (separable_conv): Conv2d(32, 32, kernel_size=(1, 15), stride=(1, 1), padding=(0, 7), groups=32, bias=False)
#   (bn3): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#   (pool3): AvgPool2d(kernel_size=(1, 8), stride=(1, 8), padding=0)
#   (dropout3): Dropout(p=0.4, inplace=False)
#   (fc1): Linear(in_features=128, out_features=3, bias=True)
# )

# %%
# !pip install onnxruntime
# Out:
# Collecting onnxruntime
#   Downloading onnxruntime-1.24.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime) (1.3.0)
# Downloading onnxruntime-1.24.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 75.0 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: onnxruntime
# Successfully installed onnxruntime-1.24.2

# %%
import onnxruntime as ort
import numpy as np

# Load the ONNX model for inference
session = ort.InferenceSession("eegnet_model.onnx")

# Prepare input - must be numpy, not torch tensor
sample = np.random.randn(1, 1, 64, 129).astype(np.float32)

# Run inference
input_name = session.get_inputs()[0].name
outputs = session.run(None, {input_name: sample})

predicted_class = np.argmax(outputs[0])
print(predicted_class)  # 0=Rest, 1=Left, 2=Right
# Out:
# 0

# %%
import onnxruntime as ort
import numpy as np
from sklearn.metrics import accuracy_score, classification_report
import torch

# %%
# ============================================
# 1. PYTORCH MODEL PREDICTIONS
# ============================================
model.eval()
model.to(device)

all_preds_torch = []
all_labels = []

with torch.no_grad():
    for X, y in test_loader:
        X = X.to(device)
        out = model(X)  # no dann=False
        preds = out.argmax(dim=1).cpu().numpy()
        all_preds_torch.extend(preds)
        all_labels.extend(y.numpy())

# ============================================
# 2. ONNX MODEL PREDICTIONS
# ============================================
session = ort.InferenceSession("eegnet_model.onnx")
input_name = session.get_inputs()[0].name

all_preds_onnx = []

for X, y in test_loader:
    X_np = X.numpy().astype(np.float32)
    output = session.run(None, {input_name: X_np})
    preds = np.argmax(output[0], axis=1)
    all_preds_onnx.extend(preds)

# ============================================
# 3. COMPARE
# ============================================
all_labels = np.array(all_labels)
all_preds_torch = np.array(all_preds_torch)
all_preds_onnx = np.array(all_preds_onnx)

print("PYTORCH ACCURACY:", accuracy_score(all_labels, all_preds_torch))
print("ONNX ACCURACY:   ", accuracy_score(all_labels, all_preds_onnx))

print("\n--- PyTorch Report ---")
print(classification_report(all_labels, all_preds_torch,
      target_names=['Rest', 'Left', 'Right']))

print("\n--- ONNX Report ---")
print(classification_report(all_labels, all_preds_onnx,
      target_names=['Rest', 'Left', 'Right']))

mismatch = np.sum(all_preds_torch != all_preds_onnx)
print(f"Prediction mismatches: {mismatch} / {len(all_labels)}")
print(f"Match rate: {100 * (1 - mismatch/len(all_labels)):.2f}%")
# Out:
# 2026-03-01 19:40:35.608866972 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:35.709603639 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:35.756776828 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:35.805623719 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:35.852563249 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:35.899809513 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:35.945981820 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:35.993188096 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.040266995 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.089832346 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.135762841 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.182985617 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.231494390 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.276904926 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.324218022 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.370984402 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.417499106 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.464353318 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.510444749 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.557765533 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.604034856 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.653752323 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.701442425 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.749028106 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.798262900 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.844492298 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.891241617 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.938204977 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:36.986852608 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.033917758 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.080444723 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.126586129 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.175265992 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.222760837 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.272301669 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.319825570 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.365583058 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.411857529 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.459591717 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.507228610 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.555909016 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.601956985 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.650985011 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.697359115 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.744571390 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.791721027 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.838659664 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.885301815 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.931563717 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:37.978572903 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.025324817 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.071986882 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.119167398 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.166424375 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.214320671 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.262196659 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.311782732 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.363226103 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.413495422 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.461034414 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.509504864 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.557039155 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.613122507 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.678348411 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.730152267 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.776826914 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.823815326 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.869318742 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.916905573 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:38.963661716 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.010528333 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.060186656 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.108114753 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.157294585 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.205668928 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.253412712 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.301590902 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.348412157 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.395336880 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.441848296 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.488431829 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.535876435 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.582731610 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.630132408 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.677278437 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.725120802 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.776038729 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.823981783 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.873825144 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.920519856 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:39.967839358 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.014372086 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.061174040 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.108859769 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.156240318 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.202428252 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.250801696 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.297637387 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.348272032 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.395241402 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.441966227 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.489296042 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.538869190 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.586993317 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.634773028 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.680665810 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.727698711 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.775258347 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.822986288 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.871028682 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.917329488 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:40.964384102 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:41.011554791 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# PYTORCH ACCURACY: 0.5304886348169321
# ONNX ACCURACY:    0.5304886348169321
#
# --- PyTorch Report ---
#               precision    recall  f1-score   support
#
#         Rest       0.62      0.72      0.66      7380
#         Left       0.44      0.38      0.41      3761
#        Right       0.37      0.30      0.33      3553
#
#     accuracy                           0.53     14694
#    macro avg       0.48      0.47      0.47     14694
# weighted avg       0.51      0.53      0.52     14694
#
#
# --- ONNX Report ---
#               precision    recall  f1-score   support
#
#         Rest       0.62      0.72      0.66      7380
#         Left       0.44      0.38      0.41      3761
#        Right       0.37      0.30      0.33      3553
#
#     accuracy                           0.53     14694
#    macro avg       0.48      0.47      0.47     14694
# weighted avg       0.51      0.53      0.52     14694
#
# Prediction mismatches: 0 / 14694
# Match rate: 100.00%
# 2026-03-01 19:40:41.059234843 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {128,3} for output output
# 2026-03-01 19:40:41.110377424 [W:onnxruntime:, execution_frame.cc:874 VerifyOutputSizes] Expected shape from model of {1,3} does not match actual shape of {102,3} for output output

# %%
import os
print(os.listdir('/kaggle/working/'))
# Out:
# ['checkpoint_epoch_40.pth', 'checkpoint_epoch_100.pth', 'checkpoint_epoch_90.pth', 'checkpoint_epoch_110.pth', 'checkpoint_epoch_20.pth', 'checkpoint_epoch_140.pth', 'checkpoint_epoch_10.pth', 'checkpoint_epoch_30.pth', 'best_eegnet_model.pth', '.virtual_documents', 'checkpoint_epoch_60.pth', 'checkpoint_epoch_50.pth', 'eegnet_model.onnx.data', 'checkpoint_epoch_130.pth', 'eegnet_model.onnx', 'checkpoint_epoch_80.pth', 'checkpoint_epoch_150.pth', 'checkpoint_epoch_120.pth', 'checkpoint_epoch_70.pth']
